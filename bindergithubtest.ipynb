# %% [markdown]
# this is a test

# %%
# try the following:
# !pip install ipywidgets==7.4.2
# !pip install bqplot

# lets import our usual stuff
import pandas as pd
import bqplot
import numpy as np
import traitlets
import ipywidgets
# %matplotlib inline
# Out:
# Collecting ipywidgets==7.4.2
#   Downloading ipywidgets-7.4.2-py2.py3-none-any.whl (111 kB)
#      -------------------------------------- 111.4/111.4 KB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipywidgets==7.4.2) (5.1.1)
# Requirement already satisfied: ipython>=4.0.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipywidgets==7.4.2) (8.0.1)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipywidgets==7.4.2) (6.7.0)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipywidgets==7.4.2) (5.1.3)
# Collecting widgetsnbextension~=3.4.0
#   Downloading widgetsnbextension-3.4.2-py2.py3-none-any.whl (2.2 MB)
#      ---------------------------------------- 2.2/2.2 MB 17.6 MB/s eta 0:00:00
# Requirement already satisfied: nest-asyncio in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.4.2) (1.5.4)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.4.2) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.4.2) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.4.2) (0.1.3)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.4.2) (7.1.2)
# Requirement already satisfied: jedi>=0.16 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (0.18.1)
# Requirement already satisfied: pygments in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (2.11.2)
# Requirement already satisfied: colorama in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (0.4.4)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (60.5.0)
# Requirement already satisfied: backcall in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (3.0.26)
# Requirement already satisfied: stack-data in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (0.1.4)
# Requirement already satisfied: pickleshare in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (0.7.5)
# Requirement already satisfied: decorator in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (5.1.1)
# Requirement already satisfied: black in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.4.2) (21.12b0)
# Requirement already satisfied: ipython-genutils in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.4.2) (0.2.0)
# Requirement already satisfied: jupyter-core in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.4.2) (4.9.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.4.2) (4.4.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (6.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.4.2) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.4.2) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.4.2) (5.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.4.2) (21.4.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.4.2) (22.3.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.4.2) (2.8.2)
# Requirement already satisfied: entrypoints in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.4.2) (0.3)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets==7.4.2) (303)
# Requirement already satisfied: nbconvert in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (6.4.1)
# Requirement already satisfied: prometheus-client in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.13.1)
# Requirement already satisfied: jinja2 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (3.0.3)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.8.0)
# Requirement already satisfied: argon2-cffi in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.13.1)
# Requirement already satisfied: wcwidth in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.4.2) (0.2.5)
# Requirement already satisfied: click>=7.1.2 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets==7.4.2) (7.1.2)
# Requirement already satisfied: tomli<2.0.0,>=0.2.6 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets==7.4.2) (1.2.2)
# Requirement already satisfied: pathspec<1,>=0.9.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets==7.4.2) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets==7.4.2) (0.4.3)
# Requirement already satisfied: platformdirs>=2 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets==7.4.2) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets==7.4.2) (4.0.1)
# Requirement already satisfied: asttokens in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.4.2) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.4.2) (0.2.2)
# Requirement already satisfied: executing in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets==7.4.2) (0.8.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets==7.4.2) (3.7.0)
# Requirement already satisfied: six>=1.5 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from python-dateutil>=2.1->jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets==7.4.2) (1.16.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (2.0.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (2.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.8.4)
# Requirement already satisfied: testpath in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.5.0)
# Requirement already satisfied: bleach in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (4.1.0)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.5.10)
# Requirement already satisfied: defusedxml in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.7.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (1.15.0)
# Requirement already satisfied: packaging in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (21.3)
# Requirement already satisfied: webencodings in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (0.5.1)
# Requirement already satisfied: pycparser in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets==7.4.2) (3.0.7)
# Installing collected packages: widgetsnbextension, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.5.2
#     Uninstalling widgetsnbextension-3.5.2:
#       Successfully uninstalled widgetsnbextension-3.5.2
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.6.5
#     Uninstalling ipywidgets-7.6.5:
#       Successfully uninstalled ipywidgets-7.6.5
# Successfully installed ipywidgets-7.4.2 widgetsnbextension-3.4.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipyleaflet 0.15.0 requires ipywidgets<8,>=7.6.0, but you have ipywidgets 7.4.2 which is incompatible.
# bqplot 0.12.30 requires ipywidgets>=7.5.0, but you have ipywidgets 7.4.2 which is incompatible.
# Requirement already satisfied: bqplot in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (0.12.30)
# Requirement already satisfied: pandas in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from bqplot) (1.4.0)
# Requirement already satisfied: traitlets>=4.3.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from bqplot) (5.1.1)
# Collecting ipywidgets>=7.5.0
#   Downloading ipywidgets-7.7.0-py2.py3-none-any.whl (123 kB)
#      -------------------------------------- 123.4/123.4 KB 7.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.10.4 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from bqplot) (1.22.1)
# Requirement already satisfied: traittypes>=0.0.6 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from bqplot) (0.2.1)
# Collecting widgetsnbextension~=3.6.0
#   Downloading widgetsnbextension-3.6.0-py2.py3-none-any.whl (1.6 MB)
#      ---------------------------------------- 1.6/1.6 MB 20.3 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=4.0.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipywidgets>=7.5.0->bqplot) (8.0.1)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipywidgets>=7.5.0->bqplot) (5.1.3)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipywidgets>=7.5.0->bqplot) (6.7.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipywidgets>=7.5.0->bqplot) (1.0.2)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipywidgets>=7.5.0->bqplot) (0.2.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from pandas->bqplot) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from pandas->bqplot) (2.8.2)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (6.1)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (7.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (1.5.1)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (0.1.3)
# Requirement already satisfied: nest-asyncio in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (1.5.4)
# Requirement already satisfied: pygments in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (2.11.2)
# Requirement already satisfied: decorator in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (3.0.26)
# Requirement already satisfied: backcall in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.2.0)
# Requirement already satisfied: colorama in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.4.4)
# Requirement already satisfied: jedi>=0.16 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.18.1)
# Requirement already satisfied: black in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (21.12b0)
# Requirement already satisfied: setuptools>=18.5 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (60.5.0)
# Requirement already satisfied: stack-data in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.1.4)
# Requirement already satisfied: pickleshare in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.7.5)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (4.4.0)
# Requirement already satisfied: jupyter-core in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (4.9.1)
# Requirement already satisfied: six>=1.5 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from python-dateutil>=2.8.1->pandas->bqplot) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (6.4.8)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (5.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (21.4.0)
# Requirement already satisfied: entrypoints in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (0.3)
# Requirement already satisfied: pyzmq>=13 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jupyter-client<8.0->ipykernel>=4.5.1->ipywidgets>=7.5.0->bqplot) (22.3.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (303)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (1.8.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (0.13.1)
# Requirement already satisfied: argon2-cffi in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (21.3.0)
# Requirement already satisfied: jinja2 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (3.0.3)
# Requirement already satisfied: prometheus-client in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (0.13.1)
# Requirement already satisfied: nbconvert in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (6.4.1)
# Requirement already satisfied: wcwidth in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.2.5)
# Requirement already satisfied: click>=7.1.2 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (7.1.2)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.4.3)
# Requirement already satisfied: tomli<2.0.0,>=0.2.6 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (1.2.2)
# Requirement already satisfied: pathspec<1,>=0.9.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.9.0)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (4.0.1)
# Requirement already satisfied: platformdirs>=2 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from black->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (2.3.0)
# Requirement already satisfied: asttokens in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (2.0.5)
# Requirement already satisfied: executing in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.8.2)
# Requirement already satisfied: pure-eval in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from stack-data->ipython>=4.0.0->ipywidgets>=7.5.0->bqplot) (0.2.2)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from importlib-resources>=1.4.0->jsonschema!=2.5.0,>=2.4->nbformat>=4.2.0->ipywidgets>=7.5.0->bqplot) (3.7.0)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (2.0.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (21.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (2.0.1)
# Requirement already satisfied: defusedxml in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (0.1.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (1.5.0)
# Requirement already satisfied: bleach in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (4.1.0)
# Requirement already satisfied: testpath in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (0.5.10)
# Requirement already satisfied: mistune<2,>=0.8.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (0.8.4)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (1.15.0)
# Requirement already satisfied: webencodings in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (0.5.1)
# Requirement already satisfied: packaging in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (21.3)
# Requirement already satisfied: pycparser in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (2.21)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\mithil\anaconda3\envs\dataviz\lib\site-packages (from packaging->bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets>=7.5.0->bqplot) (3.0.7)
# Installing collected packages: widgetsnbextension, ipywidgets
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.4.2
#     Uninstalling widgetsnbextension-3.4.2:
#       Successfully uninstalled widgetsnbextension-3.4.2
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.4.2
#     Uninstalling ipywidgets-7.4.2:
#       Successfully uninstalled ipywidgets-7.4.2
# Successfully installed ipywidgets-7.7.0 widgetsnbextension-3.6.0

# %%
data = np.random.random((10, 10))

# %%
# now add scales - colors, x & y
col_sc = bqplot.ColorScale(scheme = "Reds")
x_sc = bqplot.OrdinalScale()
y_sc = bqplot.OrdinalScale()

# create axis - for colors, x & y
c_ax = bqplot.ColorAxis(scale = col_sc, 
                        orientation = 'vertical', 
                        side = 'right')
x_ax = bqplot.Axis(scale = x_sc)
y_ax = bqplot.Axis(scale = y_sc, 
                   orientation = 'vertical')


# so now, lets write a little function that links the data value
#  to the selected & lets print this in a little ipywidgets label
mySelectedLabel = ipywidgets.Label()

# (1) 
# lets write our linking function
# there are a few ways to link this,
#  here is a simple way first
def get_data_value(change):
    i,j = heat_map.selected[0]
    v = data[i,j] # grab data value
    mySelectedLabel.value = str(v) # set our label

# (2) this is maybe in-elegant as we are 
#  explicitly calling our origininal heat map!
#  so, lets instead remind ourselves what "change" is here
def get_data_value(change):
    print(change)
    i,j = heat_map.selected[0]
    v = data[i,j] # grab data value
    mySelectedLabel.value = str(v) # set our label
# now we see when we click we get back a whole
#  dictionary of information - if we recall, 
#  "owner" here is our heat_map which "owns" 
# this change.
#  If we want to be able to apply our function to 
#  this or any other heatmap figure we generate,
#  we can re-write the above function as follows:

# (3)
#def get_data_value(change,mylab):
def get_data_value(change):
    #print(change['owner'].selected)
    i,j = change['owner'].selected[0]
    v = data[i,j] # grab data value
    mySelectedLabel.value = str(v) # set our label
    #mylab.value = str(v) # set our label
# so, this now is applied to any map that we choose to input
    
# regenerate our heatmap to use in our fig canvas
heat_map = bqplot.GridHeatMap(color = data,
                              scales = {'color': col_sc,
                                        'row': y_sc,
                                        'column': x_sc},
                              interactions = {'click': 'select'},
                              anchor_style = {'fill':'blue'}, 
                              selected_style = {'opacity': 1.0},
                              unselected_style = {'opacity': 0.8})
    
# make sure we check out     
heat_map.observe(get_data_value, 'selected')
#heat_map.observe(self, mySelectedLabel)
fig = bqplot.Figure(marks = [heat_map], 
                    axes = [c_ax, y_ax, x_ax])

ipywidgets.VBox([mySelectedLabel, fig])
# Out:
# VBox(children=(Label(value=''), Figure(axes=[ColorAxis(orientation='vertical', scale=ColorScale(scheme='Reds')…
